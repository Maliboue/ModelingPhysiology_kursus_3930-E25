# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# %% [markdown]
# # van der Pol oscillator without external forcing

# %% [markdown]
# ### Solve vanderPol oscillator for particular initial condition and parameter Mu.
#
#
# 1. Read description of the numerical integration function `solve_ivp`
# 2. Write model function (the right sides of the differential equations)
# 3. Specify mdoel parameters and run `solve_ivp` to estimate the solution

# %% [markdown]
# ### van der Pol oscillator:

# %% [markdown]
# $$
# \begin{align}
# \frac{\text{d}x}{\text{d}t} &= y\\
# \frac{\text{d}y}{\text{d}t} &= \mu (1 - x^2) y -x
# \end{align}
# $$

# %%
## Our model function
def vdp(t, state, mu=1):
    x, y = state
    return [y, mu*(1-x**2)*y - x]

# %%
state_initial = (-1, 2)
mu = 1
t_span = [0, 50]

# %%
## check that our model function returns correct values given an initial condition ant t:
vdp(0, state_initial)
# Out:
# [2, 1]

# %% [markdown]
# ## A test run: Show how state variables `x` and `y` change with time -- Limit cycle (Figure 1.1)

# %%
solution = solve_ivp(vdp, t_span, state_initial, args=(mu,), max_step = 0.1)

# %%
f,(ax, ax1, ax2) = plt.subplots(1,3, figsize=(12,3))

ax.plot(solution.t, solution.y[0, :], label='x')
ax.set_ylabel('x')
ax.set_xlabel('time')

ax1.plot(solution.t, solution.y[1, :], label='y')
ax1.set_ylabel('y')
ax1.set_xlabel('time')

ax2.plot(solution.y[0], solution.y[1])
ax2.set_xlabel('x')
ax2.set_ylabel('y')

plt.suptitle(f'van der Pol oscillator. Limit cycle. µ = {mu}')
# Out:
# Text(0.5, 0.98, 'van der Pol oscillator. Limit cycle. µ = 1')

# %% [markdown]
# # Stable focus

# %%
state_initial = (-1, 2)
mu_focus = -0.5

# %%
traj_focus = solve_ivp(vdp, [0, 30], state_initial, args=(mu_focus,), max_step = 0.01)

# %% [markdown]
# ## Show solution vs time

# %%
plt.plot(traj_focus.t, traj_focus.y[1,:], label='y')
plt.plot(traj_focus.t, traj_focus.y[0,:], label='x')
plt.legend()

# %% [markdown]
# ## Show vector field with a phase trajectory - Stable focus (Fig. 1.3)

# %%
n = 24

X, Y = np.meshgrid(np.linspace(-3, 3, n), np.linspace(-3, 3,n))

dx, dy = vdp(0, [X, Y], mu=mu_focus)

norm = np.linalg.norm([dx, dy], axis=0)

# %%
plt.figure()
plt.quiver(X, Y, dx/norm, dy/norm)
plt.plot(*traj_focus.y, color='r')
plt.xlabel('x')
plt.ylabel('y')

plt.title(f'van der Pol oscillator. Stable focus. µ = {mu_focus}')
# Out:
# Text(0.5, 1.0, 'van der Pol oscillator. Stable focus. µ = -0.5')

# %% [markdown]
# ## Vector field with multiple phase trajectories starting from different initial condition - Stable focus (Fig. 1.4)

# %% [markdown]
# #### Make trajectories

# %%
x0s = np.arange(-1, 0.1, 0.2)
y0 = state_initial[1]

trajectories = []

for x0 in x0s:

    xy_initial = (x0, y0)
    traj = solve_ivp(vdp, [0, 30], xy_initial, args=(mu_focus,), max_step = 0.01)
    traj.xy_initial = xy_initial
    
    trajectories.append(traj)

# %% [markdown]
# #### Show trajectories

# %%
plt.figure()
plt.quiver(X, Y, dx/norm, dy/norm, alpha=0.3)

for x0, traj in zip(x0s, trajectories):
    plt.plot(*traj.y, label=f"x(0) = {np.round(x0, 1)}")
plt.legend()
plt.xlabel('x')
plt.ylabel('y')

plt.title(f'van der Pol oscillator. Stable focus. µ = {mu_focus}, y(0) = {y0}')
# Out:
# Text(0.5, 1.0, 'van der Pol oscillator. Stable focus. µ = -0.5, y(0) = 2')

# %% [markdown]
# # Stable node

# %% [markdown]
# ## Vector field and phase trajectory (Fig. 1.5)

# %%
n = 25

X, Y = np.meshgrid(np.linspace(-3, 3, n), np.linspace(-3, 3,n))

mu_node = -5
dx,dy = vdp(0, [X, Y], mu=mu_node)
traj_node = solve_ivp(vdp, [0, 30], state_initial, args=(mu_node,), max_step = 0.01)

norm = np.linalg.norm([dx, dy], axis=0)

# %%
plt.figure()
plt.quiver(X, Y, dx/norm, dy/norm)

plt.plot(traj_node.y[0, :], traj_node.y[1, :], color='r')
plt.xlabel('x')
plt.ylabel('y')
plt.title(f'van der Pol oscillator. Stable node. µ = {mu_node}')
# Out:
# /var/folders/78/y9dnqx45747br_kyl_fq902c0000gn/T/ipykernel_6679/2970285404.py:2: RuntimeWarning: invalid value encountered in divide
#   plt.quiver(X, Y, dx/norm, dy/norm)
# Text(0.5, 1.0, 'van der Pol oscillator. Stable node. µ = -5')

# %% [markdown]
# ## Vector field with multiple phase trajectories starting from different initial condition - Stable node (Fig. 1.6)

# %% [markdown]
# #### Make trajectories

# %%
x0s = np.arange(-1.4, 0.1, 0.2)
# y0 = state_initial[1]

trajectories = []

for x0 in x0s:

    xy_initial = (x0, y0)
    traj = solve_ivp(vdp, [0, 30], xy_initial, args=(mu_node,), max_step = 0.01)
    traj.xy_initial = xy_initial
    
    trajectories.append(traj)

# %% [markdown]
# #### Show trajectories

# %%
plt.figure()
plt.quiver(X, Y, dx/norm, dy/norm, alpha=0.3)

for x0, traj in zip(x0s, trajectories):
    plt.plot(*traj.y, label=f"x(0) = {np.round(x0, 1)}")
plt.legend()
plt.xlabel('x')
plt.ylabel('y')

plt.title(f'van der Pol oscillator. Stable node. µ = {mu_node}, y(0) = {y0}')
# Out:
# /var/folders/78/y9dnqx45747br_kyl_fq902c0000gn/T/ipykernel_6679/2380973395.py:2: RuntimeWarning: invalid value encountered in divide
#   plt.quiver(X, Y, dx/norm, dy/norm, alpha=0.3)
# Text(0.5, 1.0, 'van der Pol oscillator. Stable node. µ = -5, y(0) = 2')

# %% [markdown]
# # Limit cycle

# %% [markdown]
# ## Multiple trajectories on the vector field

# %%
n = 25

X, Y = np.meshgrid(np.linspace(-3, 3, n), np.linspace(-3, 3,n))

dx,dy = vdp(0, [X, Y], mu=mu)
traj_node = solve_ivp(vdp, [0, 30], state_initial, args=(mu,), max_step = 0.01)

norm = np.linalg.norm([dx, dy], axis=0)

# %% [markdown]
# #### Make trajectories

# %%
states_initial = np.array([np.arange(-1.4, 0.1, 0.3),
                           np.linspace(2, 0, x0s.size)])

trajectories = []

for x0, y0 in states_initial.T:

    traj = solve_ivp(vdp, [0, 30], (x0, y0), args=(mu,), max_step = 0.01)
    traj.xy_initial = xy_initial
    
    trajectories.append(traj)

# %% [markdown]
# #### Show trajectories

# %%
plt.figure()
plt.quiver(X, Y, dx/norm, dy/norm, alpha=0.3)

for (x0, y0), traj in zip(states_initial.T, trajectories):
    plt.plot(*traj.y, label=f"({np.round(x0, 1)}, {np.round(y0, 1)})")
plt.legend()
plt.xlabel('x')
plt.ylabel('y')

plt.title(f'van der Pol oscillator. Limit cycle. µ = {mu}, y(0) = {y0}')
# Out:
# /var/folders/78/y9dnqx45747br_kyl_fq902c0000gn/T/ipykernel_6679/2322260466.py:2: RuntimeWarning: invalid value encountered in divide
#   plt.quiver(X, Y, dx/norm, dy/norm, alpha=0.3)
# Text(0.5, 1.0, 'van der Pol oscillator. Limit cycle. µ = 1, y(0) = 0.0')

# %% [markdown]
# # Chaos in van der Pol oscillator with external forcing (Fig. 1.9, modified)

# %% [markdown]
# We model the external force as a periodic function of time

# %% [markdown]
# ### model:

# %% [markdown]
# $$
# \begin{align}
# \frac{\text{d}x}{\text{d}t} &= y\\
# \frac{\text{d}y}{\text{d}t} &= \mu (1 - x^2) y -x + a * sin(w t)
# \end{align}
# $$

# %%
## Our model function
def vdp_forced(t, state, mu=1, a=1, w=1):
    x, y = state
    return [y, mu*(1-x**2)*y - x + a*np.sin(w*t)]

# %%
state_initial = (-1, 2)
mu_chaos = 8.53
a_chaos = 1.2 
w_chaos = 2*np.pi/10

# %%
solution = solve_ivp(vdp_forced, [0, 500], 
                     state_initial, 
                     args=(mu_chaos, a_chaos, w_chaos), 
                     max_step = 0.01)

# %% [markdown]
# ### Visualize results

# %% [markdown]
# Show how state variables `x` and `y` change with time and the phase trajectory

# %% [raw]
# %matplotlib widget

# %%
f,(ax, ax1, ax2) = plt.subplots(1,3, figsize=(15,4))
plt.subplots_adjust(wspace=0.3)

plt.suptitle('van der Pol oscillator. Chaos', fontsize=15)

ax.plot(solution.t, solution.y[0, :])
ax.set_ylabel('x')
ax.set_xlabel('t')
ax.set_xlim(100, 200)

ax1.plot(solution.y[0, :], solution.y[1, :], lw=0.2)
ax1.set_title('Phase trajectory')
ax1.set_ylabel('y')
ax1.set_xlabel('x')

xy0, w, h = (-2.15, -0.8), 1.5, 2
# xy0, w, h = (0.7, -0.8), 1.5, 2
ax1.add_patch(plt.Rectangle(xy0, w, h, fill=False, color='r'))


ax2.plot(solution.y[0, :], solution.y[1, :], lw=0.2)
ax2.set_title('Phase trajectory in red rectangle')
ax2.set_xlim(xy0[0], xy0[0]+w)
ax2.set_ylim(xy0[1], xy0[1]+h)
ax2.set_ylabel('y')
ax2.set_xlabel('x')
# Out:
# Text(0.5, 0, 'x')
